# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import figure
### importing WITS dataset package
import world_trade_data as wits

# %%
### getting countries list 
countries=wits.get_countries()

mex=countries.loc[countries['name'] == 'Mexico']
ind=countries.loc[countries['name'] == 'India']
usa=countries.loc[countries['name'] == 'United States']

# %%
#### Creating Mexico trade dataframe

# %%
### importing import volume dataset fron 2004-2020


mexico_imports2006=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2006', product='Total')
mexico_imports2007=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2007', product='Total')
mexico_imports2008=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2008', product='Total')
mexico_imports2009=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2009', product='Total')
mexico_imports2010=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2010', product='Total')
mexico_imports2011=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2011', product='Total')
mexico_imports2012=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2012', product='Total')
mexico_imports2013=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2013', product='Total')
mexico_imports2014=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2014', product='Total')
mexico_imports2015=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2015', product='Total')
mexico_imports2016=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2016', product='Total')
mexico_imports2017=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2017', product='Total')
mexico_imports2018=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2018', product='Total')
mexico_imports2019=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2019', product='Total')
mexico_imports2020=wits.get_indicator('MPRT-TRD-VL', reporter='mex',  year ='2020', product='Total')

# %%
### importing export volume dataset from 2004-2020
mexico_exports2006=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2006', product='Total')
mexico_exports2007=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2007', product='Total')
mexico_exports2008=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2008', product='Total')
mexico_exports2009=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2009', product='Total')
mexico_exports2010=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2010', product='Total')
mexico_exports2011=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2011', product='Total')
mexico_exports2012=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2012', product='Total')
mexico_exports2013=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2013', product='Total')
mexico_exports2014=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2014', product='Total')
mexico_exports2015=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2015', product='Total')
mexico_exports2016=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2016', product='Total')
mexico_exports2017=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2017', product='Total')
mexico_exports2018=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2018', product='Total')
mexico_exports2019=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2019', product='Total')
mexico_exports2020=wits.get_indicator('XPRT-TRD-VL', reporter='mex',  year='2020', product='Total')

# %%
list_mexico_imports=[mexico_imports2006,mexico_imports2007,mexico_imports2008,mexico_imports2009,mexico_imports2010,mexico_imports2011,mexico_imports2012,mexico_imports2013,mexico_imports2014,mexico_imports2015,mexico_imports2016,mexico_imports2017,mexico_imports2018,mexico_imports2019,mexico_imports2020]

# %%
list_mexico_exports=[mexico_exports2006,mexico_exports2007,mexico_exports2008,mexico_exports2009,mexico_exports2010,mexico_exports2011,mexico_exports2012,mexico_exports2013,mexico_exports2014,mexico_exports2015,mexico_exports2016,mexico_exports2017,mexico_exports2018,mexico_exports2019,mexico_exports2020]

# %%
for dataframe in list_mexico_imports:
    dataframe.reset_index(inplace=True)

for dataframe in list_mexico_exports:
    dataframe.reset_index(inplace=True)

for dataframe in list_mexico_imports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

for dataframe in list_mexico_exports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

# %%
mexico_imports=[df.set_index('Year') for df in list_mexico_imports]

mexico_imports=pd.concat(mexico_imports, axis=0)

mexico_imports=mexico_imports.reset_index()

mexico_imports=mexico_imports.rename(columns={'Value':'Imports'})

# %%
mexico_exports=[df.set_index('Year') for df in list_mexico_exports]
mexico_exports=pd.concat(mexico_exports, axis=0)
mexico_exports=mexico_exports.reset_index()
mexico_exports=mexico_exports.rename(columns={'Value':'Exports'})

mexico_currentaccount=pd.merge(mexico_imports,mexico_exports)

# %%
mexico_currentaccount['Current Account']=mexico_currentaccount['Exports']-mexico_currentaccount['Imports']

mexico_currentaccount
# Out:
#     Year       Imports       Exports  Current Account
# 0   2006  2.560859e+08  2.499605e+08    -6.125375e+06
# 1   2007  2.819265e+08  2.718212e+08    -1.010530e+07
# 2   2008  3.085831e+08  2.912648e+08    -1.731831e+07
# 3   2009  2.343845e+08  2.297123e+08    -4.672195e+06
# 4   2010  3.014817e+08  2.983051e+08    -3.176659e+06
# 5   2011  3.508428e+08  3.493266e+08    -1.516224e+06
# 6   2012  3.707514e+08  3.706426e+08    -1.088556e+05
# 7   2013  3.812101e+08  3.799493e+08    -1.260876e+06
# 8   2014  3.999842e+08  3.968905e+08    -3.093775e+06
# 9   2015  3.952539e+08  3.805561e+08    -1.469777e+07
# 10  2016  3.870874e+08  3.739536e+08    -1.313380e+07
# 11  2017  4.203946e+08  4.093963e+08    -1.099832e+07
# 12  2018  4.642943e+08  4.506840e+08    -1.361024e+07
# 13  2019  4.552358e+08  4.606037e+08     5.367911e+06
# 14  2020  3.829799e+08  4.169822e+08     3.400227e+07

# %%
#### Graphing 
mexico_currentaccount.plot.bar(x='Year', y='Imports', title='Mexico Imports')
# Out:
# <AxesSubplot:title={'center':'Mexico Imports'}, xlabel='Year'>

# %%
mexico_currentaccount.plot.bar(x='Year', y='Exports', title='Mexico Exports')
# Out:
# <AxesSubplot:title={'center':'Mexico Exports'}, xlabel='Year'>

# %%
mexico_currentaccount.plot.bar(x='Year', y='Current Account', title='Current Account with US imports and Exports to US ')
# Out:
# <AxesSubplot:title={'center':'Current Account with US imports and Exports to US '}, xlabel='Year'>

# %%
### creating India Trade Dataframe 
### importing import volume dataset fron 2004-2020

india_imports2006=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2006', product='Total')
india_imports2007=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2007', product='Total')
india_imports2008=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2008', product='Total')
india_imports2009=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2009', product='Total')
india_imports2010=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2010', product='Total')
india_imports2011=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2011', product='Total')
india_imports2012=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2012', product='Total')
india_imports2013=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2013', product='Total')
india_imports2014=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2014', product='Total')
india_imports2015=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2015', product='Total')
india_imports2016=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2016', product='Total')
india_imports2017=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2017', product='Total')
india_imports2018=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2018', product='Total')
india_imports2019=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2019', product='Total')
india_imports2020=wits.get_indicator('MPRT-TRD-VL', reporter='ind',  year ='2020', product='Total')

# %%
### getting export trade volume 

india_exports2006=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2006', product='Total')
india_exports2007=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2007', product='Total')
india_exports2008=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2008', product='Total')
india_exports2009=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2009', product='Total')
india_exports2010=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2010', product='Total')
india_exports2011=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2011', product='Total')
india_exports2012=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2012', product='Total')
india_exports2013=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2013', product='Total')
india_exports2014=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2014', product='Total')
india_exports2015=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2015', product='Total')
india_exports2016=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2016', product='Total')
india_exports2017=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2017', product='Total')
india_exports2018=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2018', product='Total')
india_exports2019=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2019', product='Total')
india_exports2020=wits.get_indicator('XPRT-TRD-VL', reporter='ind',  year='2020', product='Total')

# %%
list_india_imports=[india_imports2006,india_imports2007,india_imports2008,india_imports2009,india_imports2010,india_imports2011,india_imports2012,india_imports2013,india_imports2014,india_imports2015,india_imports2016,india_imports2017,india_imports2018,india_imports2019,india_imports2020]
list_india_exports=[india_exports2006,india_exports2007,india_exports2008,india_exports2009,india_exports2010,india_exports2011,india_exports2012,india_exports2013,india_exports2014,india_exports2015,india_exports2016,india_exports2017,india_exports2018,india_exports2019,india_exports2020]

# %%
for dataframe in list_india_imports:
    dataframe.reset_index(inplace=True)

for dataframe in list_india_exports:
    dataframe.reset_index(inplace=True)

for dataframe in list_india_imports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

for dataframe in list_india_exports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

# %%
india_imports=[df.set_index('Year') for df in list_india_imports]

india_imports=pd.concat(india_imports, axis=0)

india_imports=india_imports.reset_index()

india_imports=india_imports.rename(columns={'Value':'Imports'})

# %%
india_exports=[df.set_index('Year') for df in list_india_exports]
india_exports=pd.concat(india_exports, axis=0)
india_exports=india_exports.reset_index()
india_exports=india_exports.rename(columns={'Value':'Exports'})

india_currentaccount=pd.merge(india_imports,india_exports)

# %%
india_currentaccount['Current Account']=india_currentaccount['Exports']-india_currentaccount['Imports']

india_currentaccount
# Out:
#     Year       Imports       Exports  Current Account
# 0   2006  1.782124e+08  1.212006e+08    -5.701183e+07
# 1   2007  2.186453e+08  1.458981e+08    -7.274724e+07
# 2   2008  3.157121e+08  1.818609e+08    -1.338512e+08
# 3   2009  2.664016e+08  1.767650e+08    -8.963652e+07
# 4   2010  3.500294e+08  2.204085e+08    -1.296209e+08
# 5   2011  4.624028e+08  3.014833e+08    -1.609195e+08
# 6   2012  4.889764e+08  2.895648e+08    -1.994116e+08
# 7   2013  4.660456e+08  3.366114e+08    -1.294342e+08
# 8   2014  4.593695e+08  3.175446e+08    -1.418248e+08
# 9   2015  3.907447e+08  2.643810e+08    -1.263637e+08
# 10  2016  3.567048e+08  2.603269e+08    -9.637788e+07
# 11  2017  4.440524e+08  2.943645e+08    -1.496879e+08
# 12  2018  6.179456e+08  3.222916e+08    -2.956540e+08
# 13  2019  4.788837e+08  3.232507e+08    -1.556330e+08
# 14  2020  3.679804e+08  2.754887e+08    -9.249162e+07

# %%
india_currentaccount.plot.bar(x='Year', y='Imports', title=' India Imports')
# Out:
# <AxesSubplot:title={'center':' India Imports'}, xlabel='Year'>

# %%
india_currentaccount.plot.bar(x='Year', y='Exports', title=' India Exports')
# Out:
# <AxesSubplot:title={'center':' India Exports'}, xlabel='Year'>

# %%
india_currentaccount.plot.bar(x='Year', y='Current Account', title='Current Account with US imports and Exports to US ')
# Out:
# <AxesSubplot:title={'center':'Current Account with US imports and Exports to US '}, xlabel='Year'>

# %%
#### donwloading the interest rate differential data

# %%
India10yryield=pd.read_csv('/Users/ishaansm/Desktop/RateDifferentials/India 10-Year Bond Yield Historical Data (6).csv')
Mexico10yryield=pd.read_csv('/Users/ishaansm/Desktop/RateDifferentials/Mexico 10-Year Bond Yield Historical Data (6).csv')
US10yryield=pd.read_csv('/Users/ishaansm/Desktop/RateDifferentials/United States 10-Year Bond Yield Historical Data (4).csv')

# %%
### merging current account dataset and interest rate differential dataset

# %%
India10yryield
# Out:
#               Date  Price   Open   High    Low Change %
# 0     Dec 31, 2020  5.894  5.905  5.905  5.887   -0.08%
# 1     Dec 30, 2020  5.899  5.933  5.933  5.899   -0.47%
# 2     Dec 29, 2020  5.927  5.935  5.935  5.924    0.03%
# 3     Dec 28, 2020  5.925  5.918  5.928  5.918   -0.07%
# 4     Dec 24, 2020  5.929  5.973  5.981  5.929   -0.35%
# ...            ...    ...    ...    ...    ...      ...
# 4377  Jan 06, 2004  5.116  5.116  5.116  5.116   -0.08%
# 4378  Jan 05, 2004  5.120  5.120  5.120  5.120    0.55%
# 4379  Jan 03, 2004  5.092  5.092  5.092  5.092   -0.57%
# 4380  Jan 02, 2004  5.121  5.121  5.121  5.121   -0.12%
# 4381  Jan 01, 2004  5.127  5.127  5.127  5.127    0.10%
#
# [4382 rows x 6 columns]

# %%
#### reversing order
India10yryield=India10yryield.iloc[::-1]
US10yryield=US10yryield.iloc[::-1]
Mexico10yryield=Mexico10yryield.iloc[::-1]

## making list 
list_of_yields=[India10yryield, US10yryield, Mexico10yryield]


#### deleting columns 

for dataframe in list_of_yields:
    dataframe=dataframe.drop(columns=['Open', 'High', 'Low', 'Change %'], inplace=True)
# Out:
# /var/folders/b8/knfn6wfd3dv6wgqmpc368y6c0000gn/T/ipykernel_65119/3049172263.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe=dataframe.drop(columns=['Open', 'High', 'Low', 'Change %'], inplace=True)

# %%
### creating columns for differentials
India10yryield=India10yryield.rename(columns={'Price':'India10yryield'})
Mexico10yryield=Mexico10yryield.rename(columns={'Price':'Mexico10yryield'})
US10yryield=US10yryield.rename(columns={'Price':'US10yryield'})

# %%
### mergiing india and mexico yields with us yields
IndiaUS10yryield=pd.merge(India10yryield,US10yryield)
MexicoUS10yryield=pd.merge(Mexico10yryield, US10yryield)

# %%
### getting yield calculation
IndiaUS10yryield['India-US Differential']=IndiaUS10yryield['India10yryield']-IndiaUS10yryield['US10yryield']
MexicoUS10yryield['Mexico-US Differential']=MexicoUS10yryield['Mexico10yryield']-MexicoUS10yryield['US10yryield']

# %%
IndiaUS10yryield
# Out:
#               Date  India10yryield  US10yryield  India-US Differential
# 0     Jan 01, 2004           5.127        4.253                  0.874
# 1     Jan 02, 2004           5.121        4.374                  0.747
# 2     Jan 05, 2004           5.120        4.380                  0.740
# 3     Jan 06, 2004           5.116        4.274                  0.842
# 4     Jan 07, 2004           5.119        4.245                  0.874
# ...            ...             ...          ...                    ...
# 3917  Dec 26, 2019           6.576        1.894                  4.682
# 3918  Dec 27, 2019           6.500        1.877                  4.623
# 3919  Dec 30, 2019           6.544        1.886                  4.658
# 3920  Dec 31, 2019           6.554        1.919                  4.635
# 3921  Jan 01, 2020           6.501        1.921                  4.580
#
# [3922 rows x 4 columns]

# %%
MexicoUS10yryield
# Out:
#               Date  Mexico10yryield  US10yryield  Mexico-US Differential
# 0     Jul 13, 2006             8.69        5.067                   3.623
# 1     Jul 14, 2006             8.60        5.067                   3.533
# 2     Jul 17, 2006             8.60        5.069                   3.531
# 3     Jul 18, 2006             8.66        5.136                   3.524
# 4     Jul 19, 2006             8.47        5.055                   3.415
# ...            ...              ...          ...                     ...
# 3424  Dec 24, 2019             6.87        1.903                   4.967
# 3425  Dec 26, 2019             6.84        1.894                   4.946
# 3426  Dec 27, 2019             6.81        1.877                   4.933
# 3427  Dec 30, 2019             6.82        1.886                   4.934
# 3428  Dec 31, 2019             6.84        1.919                   4.921
#
# [3429 rows x 4 columns]

# %%
IndiaUS10yryield['Date']=pd.to_datetime(IndiaUS10yryield['Date'])

# %%
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'

start_date_17='2017-01-01'
end_date_17='2017-12-31'

start_date_18='2018-01-01'
end_date_18='2018-12-31'

start_date_19='2019-01-01'
end_date_19='2019-12-31'

#start_date_20='2020-01-01'
#end_date_20='2020-12-31'



year06 = (IndiaUS10yryield['Date'] > start_date_06) & (IndiaUS10yryield['Date'] <= end_date_06)
year07 = (IndiaUS10yryield['Date'] > start_date_07) & (IndiaUS10yryield['Date'] <= end_date_07)
year08 = (IndiaUS10yryield['Date'] > start_date_08) & (IndiaUS10yryield['Date'] <= end_date_08)
year09 = (IndiaUS10yryield['Date'] > start_date_09) & (IndiaUS10yryield['Date'] <= end_date_09)
year10 = (IndiaUS10yryield['Date'] > start_date_10) & (IndiaUS10yryield['Date'] <= end_date_10)
year10 = (IndiaUS10yryield['Date'] > start_date_10) & (IndiaUS10yryield['Date'] <= end_date_10)
year11 = (IndiaUS10yryield['Date'] > start_date_11) & (IndiaUS10yryield['Date'] <= end_date_11)
year12 = (IndiaUS10yryield['Date'] > start_date_12) & (IndiaUS10yryield['Date'] <= end_date_12)
year13 = (IndiaUS10yryield['Date'] > start_date_13) & (IndiaUS10yryield['Date'] <= end_date_13)
year14 = (IndiaUS10yryield['Date'] > start_date_14) & (IndiaUS10yryield['Date'] <= end_date_14)
year15 = (IndiaUS10yryield['Date'] > start_date_15) & (IndiaUS10yryield['Date'] <= end_date_15)
year16 = (IndiaUS10yryield['Date'] > start_date_16) & (IndiaUS10yryield['Date'] <= end_date_16)
year17 = (IndiaUS10yryield['Date'] > start_date_17) & (IndiaUS10yryield['Date'] <= end_date_17)
year18 = (IndiaUS10yryield['Date'] > start_date_18) & (IndiaUS10yryield['Date'] <= end_date_18)
year19 = (IndiaUS10yryield['Date'] > start_date_19) & (IndiaUS10yryield['Date'] <= end_date_19)
#year20 = (IndiaUS10yryield['Date'] > start_date_20) & (IndiaUS10yryield['Date'] <= end_date_20)

# %%
IndiaUS10yr06=IndiaUS10yryield.loc[year06]
IndiaUS10yr07=IndiaUS10yryield.loc[year07]
IndiaUS10yr08=IndiaUS10yryield.loc[year08]
IndiaUS10yr09=IndiaUS10yryield.loc[year09]
IndiaUS10yr10=IndiaUS10yryield.loc[year10]
IndiaUS10yr11=IndiaUS10yryield.loc[year11]
IndiaUS10yr12=IndiaUS10yryield.loc[year12]
IndiaUS10yr13=IndiaUS10yryield.loc[year13]
IndiaUS10yr14=IndiaUS10yryield.loc[year14]
IndiaUS10yr15=IndiaUS10yryield.loc[year15]
IndiaUS10yr16=IndiaUS10yryield.loc[year16]
IndiaUS10yr17=IndiaUS10yryield.loc[year17]
IndiaUS10yr18=IndiaUS10yryield.loc[year18]
IndiaUS10yr19=IndiaUS10yryield.loc[year19]
#IndiaUS10yr20=IndiaUS10yryield.loc[year20]

# %%
Inddiff06=IndiaUS10yr06['India-US Differential'].mean()
Inddiff07=IndiaUS10yr07['India-US Differential'].mean()
Inddiff08=IndiaUS10yr08['India-US Differential'].mean()
Inddiff09=IndiaUS10yr09['India-US Differential'].mean()
Inddiff10=IndiaUS10yr10['India-US Differential'].mean()
Inddiff11=IndiaUS10yr11['India-US Differential'].mean()
Inddiff12=IndiaUS10yr12['India-US Differential'].mean()
Inddiff13=IndiaUS10yr13['India-US Differential'].mean()
Inddiff14=IndiaUS10yr14['India-US Differential'].mean()
Inddiff15=IndiaUS10yr15['India-US Differential'].mean()
Inddiff16=IndiaUS10yr16['India-US Differential'].mean()
Inddiff17=IndiaUS10yr17['India-US Differential'].mean()
Inddiff18=IndiaUS10yr18['India-US Differential'].mean()
Inddiff19=IndiaUS10yr19['India-US Differential'].mean()
#Inddiff20=IndiaUS10yr20['India-US Differential'].mean()

# %%
### creating new dataframe 
data= [['2006', Inddiff06],['2007', Inddiff07],['2008', Inddiff08],['2009', Inddiff09],['2010', Inddiff10],['2011', Inddiff11],['2012', Inddiff12],['2013', Inddiff13],['2014', Inddiff14],['2015', Inddiff15],['2016', Inddiff16],['2017', Inddiff17],['2018', Inddiff18],['2019', Inddiff19]]
Indiadiff=pd.DataFrame(data,columns=['Year', 'India-US Interest Rate Differential'])
Indiadiff
# Out:
#     Year  India-US Interest Rate Differential
# 0   2006                             2.861494
# 1   2007                             3.319214
# 2   2008                             4.296662
# 3   2009                             3.600819
# 4   2010                             4.669687
# 5   2011                             5.564233
# 6   2012                             6.490532
# 7   2013                             5.790500
# 8   2014                             6.048088
# 9   2015                             5.625702
# 10  2016                             5.393923
# 11  2017                             4.391008
# 12  2018                             4.809645
# 13  2019                             4.824398

# %%
MexicoUS10yryield['Date']=pd.to_datetime(MexicoUS10yryield['Date'])

# %%
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'

start_date_17='2017-01-01'
end_date_17='2017-12-31'

start_date_18='2018-01-01'
end_date_18='2018-12-31'

start_date_19='2019-01-01'
end_date_19='2019-12-31'

#start_date_20='2020-01-01'
#end_date_20='2020-12-31'



year06 = (MexicoUS10yryield['Date'] > start_date_06) & (MexicoUS10yryield['Date'] <= end_date_06)
year07 = (MexicoUS10yryield['Date'] > start_date_07) & (MexicoUS10yryield['Date'] <= end_date_07)
year08 = (MexicoUS10yryield['Date'] > start_date_08) & (MexicoUS10yryield['Date'] <= end_date_08)
year09 = (MexicoUS10yryield['Date'] > start_date_09) & (MexicoUS10yryield['Date'] <= end_date_09)
year10 = (MexicoUS10yryield['Date'] > start_date_10) & (MexicoUS10yryield['Date'] <= end_date_10)
year10 = (MexicoUS10yryield['Date'] > start_date_10) & (MexicoUS10yryield['Date'] <= end_date_10)
year11 = (MexicoUS10yryield['Date'] > start_date_11) & (MexicoUS10yryield['Date'] <= end_date_11)
year12 = (MexicoUS10yryield['Date'] > start_date_12) & (MexicoUS10yryield['Date'] <= end_date_12)
year13 = (MexicoUS10yryield['Date'] > start_date_13) & (MexicoUS10yryield['Date'] <= end_date_13)
year14 = (MexicoUS10yryield['Date'] > start_date_14) & (MexicoUS10yryield['Date'] <= end_date_14)
year15 = (MexicoUS10yryield['Date'] > start_date_15) & (MexicoUS10yryield['Date'] <= end_date_15)
year16 = (MexicoUS10yryield['Date'] > start_date_16) & (MexicoUS10yryield['Date'] <= end_date_16)
year17 = (MexicoUS10yryield['Date'] > start_date_17) & (MexicoUS10yryield['Date'] <= end_date_17)
year18 = (MexicoUS10yryield['Date'] > start_date_18) & (MexicoUS10yryield['Date'] <= end_date_18)
year19 = (MexicoUS10yryield['Date'] > start_date_19) & (MexicoUS10yryield['Date'] <= end_date_19)
#year20 = (IndiaUS10yryield['Date'] > start_date_20) & (IndiaUS10yryield['Date'] <= end_date_20)

# %%
MexicoUS10yr06=MexicoUS10yryield.loc[year06]
MexicoUS10yr07=MexicoUS10yryield.loc[year07]
MexicoUS10yr08=MexicoUS10yryield.loc[year08]
MexicoUS10yr09=MexicoUS10yryield.loc[year09]
MexicoUS10yr10=MexicoUS10yryield.loc[year10]
MexicoUS10yr11=MexicoUS10yryield.loc[year11]
MexicoUS10yr12=MexicoUS10yryield.loc[year12]
MexicoUS10yr13=MexicoUS10yryield.loc[year13]
MexicoUS10yr14=MexicoUS10yryield.loc[year14]
MexicoUS10yr15=MexicoUS10yryield.loc[year15]
MexicoUS10yr16=MexicoUS10yryield.loc[year16]
MexicoUS10yr17=MexicoUS10yryield.loc[year17]
MexicoUS10yr18=MexicoUS10yryield.loc[year18]
MexicoUS10yr19=MexicoUS10yryield.loc[year19]
#IndiaUS10yr20=IndiaUS10yryield.loc[year20]

# %%
Mexicodiff06=MexicoUS10yr06['Mexico-US Differential'].mean()
Mexicodiff07=MexicoUS10yr07['Mexico-US Differential'].mean()
Mexicodiff08=MexicoUS10yr08['Mexico-US Differential'].mean()
Mexicodiff09=MexicoUS10yr09['Mexico-US Differential'].mean()
Mexicodiff10=MexicoUS10yr10['Mexico-US Differential'].mean()
Mexicodiff11=MexicoUS10yr11['Mexico-US Differential'].mean()
Mexicodiff12=MexicoUS10yr12['Mexico-US Differential'].mean()
Mexicodiff13=MexicoUS10yr13['Mexico-US Differential'].mean()
Mexicodiff14=MexicoUS10yr14['Mexico-US Differential'].mean()
Mexicodiff15=MexicoUS10yr15['Mexico-US Differential'].mean()
Mexicodiff16=MexicoUS10yr16['Mexico-US Differential'].mean()
Mexicodiff17=MexicoUS10yr17['Mexico-US Differential'].mean()
Mexicodiff18=MexicoUS10yr18['Mexico-US Differential'].mean()
Mexicodiff19=MexicoUS10yr19['Mexico-US Differential'].mean()
#Inddiff20=IndiaUS10yr20['India-US Differential'].mean()

# %%
data= [['2006', Mexicodiff06],['2007', Mexicodiff07],['2008', Mexicodiff08],['2009', Mexicodiff09],['2010', Mexicodiff10],['2011', Mexicodiff11],['2012', Mexicodiff12],['2013', Mexicodiff13],['2014', Mexicodiff14],['2015', Mexicodiff15],['2016', Mexicodiff16],['2017', Mexicodiff17],['2018', Mexicodiff18],['2019', Mexicodiff19]]
Mexdiff=pd.DataFrame(data,columns=['Year', 'Mexico-US Interest Rate Differential'])
Mexdiff
# Out:
#     Year  Mexico-US Interest Rate Differential
# 0   2006                              3.316378
# 1   2007                              3.126077
# 2   2008                              4.806262
# 3   2009                              4.701614
# 4   2010                              3.762237
# 5   2011                              4.062167
# 6   2012                              3.909133
# 7   2013                              3.150548
# 8   2014                              3.451363
# 9   2015                              3.800653
# 10  2016                              4.363974
# 11  2017                              4.792467
# 12  2018                              5.001508
# 13  2019                              5.443937

# %%
Mexdiff.dtypes
# Out:
# Year                                     object
# Mexico-US Interest Rate Differential    float64
# dtype: object

# %%
mexico_currentaccount.dtypes
# Out:
# Year                object
# Imports            float64
# Exports            float64
# Current Account    float64
# dtype: object

# %%
Mexico_currentaccount_differential=pd.merge(Mexdiff,mexico_currentaccount)

# %%
Mexico_currentaccount_differential
# Out:
#     Year  Mexico-US Interest Rate Differential       Imports       Exports  \
# 0   2006                              3.316378  2.560859e+08  2.499605e+08
# 1   2007                              3.126077  2.819265e+08  2.718212e+08
# 2   2008                              4.806262  3.085831e+08  2.912648e+08
# 3   2009                              4.701614  2.343845e+08  2.297123e+08
# 4   2010                              3.762237  3.014817e+08  2.983051e+08
# 5   2011                              4.062167  3.508428e+08  3.493266e+08
# 6   2012                              3.909133  3.707514e+08  3.706426e+08
# 7   2013                              3.150548  3.812101e+08  3.799493e+08
# 8   2014                              3.451363  3.999842e+08  3.968905e+08
# 9   2015                              3.800653  3.952539e+08  3.805561e+08
# 10  2016                              4.363974  3.870874e+08  3.739536e+08
# ...

# %%
India_currentaccount_differential=pd.merge(Indiadiff, india_currentaccount)

# %%
India_currentaccount_differential
# Out:
#     Year  India-US Interest Rate Differential       Imports       Exports  \
# 0   2006                             2.861494  1.782124e+08  1.212006e+08
# 1   2007                             3.319214  2.186453e+08  1.458981e+08
# 2   2008                             4.296662  3.157121e+08  1.818609e+08
# 3   2009                             3.600819  2.664016e+08  1.767650e+08
# 4   2010                             4.669687  3.500294e+08  2.204085e+08
# 5   2011                             5.564233  4.624028e+08  3.014833e+08
# 6   2012                             6.490532  4.889764e+08  2.895648e+08
# 7   2013                             5.790500  4.660456e+08  3.366114e+08
# 8   2014                             6.048088  4.593695e+08  3.175446e+08
# 9   2015                             5.625702  3.907447e+08  2.643810e+08
# 10  2016                             5.393923  3.567048e+08  2.603269e+08
# 11  2017                             4.391008  4.440524e+08  2.943645e+08
# ...

# %%
Mexico_currentaccount_differential.corr()
# Out:
#                                       Mexico-US Interest Rate Differential  \
# Mexico-US Interest Rate Differential                              1.000000
# Imports                                                           0.404200
# Exports                                                           0.392375
# Current Account                                                  -0.091367
#
#                                        Imports   Exports  Current Account
# Mexico-US Interest Rate Differential  0.404200  0.392375        -0.091367
# Imports                               1.000000  0.995776         0.046314
# Exports                               0.995776  1.000000         0.137832
# Current Account                       0.046314  0.137832         1.000000

# %%
India_currentaccount_differential.corr()
# Out:
#                                      India-US Interest Rate Differential  \
# India-US Interest Rate Differential                             1.000000
# Imports                                                         0.723498
# Exports                                                         0.807817
# Current Account                                                -0.484766
#
#                                       Imports   Exports  Current Account
# India-US Interest Rate Differential  0.723498  0.807817        -0.484766
# Imports                              1.000000  0.932048        -0.896068
# Exports                              0.932048  1.000000        -0.674332
# Current Account                     -0.896068 -0.674332         1.000000

# %%
mexico_USimports2006=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2006', product='Total')
mexico_USimports2007=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2007', product='Total')
mexico_USimports2008=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2008', product='Total')
mexico_USimports2009=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2009', product='Total')
mexico_USimports2010=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2010', product='Total')
mexico_USimports2011=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2011', product='Total')
mexico_USimports2012=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2012', product='Total')
mexico_USimports2013=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2013', product='Total')
mexico_USimports2014=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2014', product='Total')
mexico_USimports2015=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2015', product='Total')
mexico_USimports2016=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2016', product='Total')
mexico_USimports2017=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2017', product='Total')
mexico_USimports2018=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2018', product='Total')
mexico_USimports2019=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2019', product='Total')
mexico_USimports2020=wits.get_indicator('MPRT-TRD-VL', reporter='mex', partner='usa', year ='2020', product='Total')

# %%
mexico_USexports2006=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2006', product='Total')
mexico_USexports2007=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2007', product='Total')
mexico_USexports2008=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2008', product='Total')
mexico_USexports2009=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2009', product='Total')
mexico_USexports2010=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2010', product='Total')
mexico_USexports2011=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2011', product='Total')
mexico_USexports2012=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2012', product='Total')
mexico_USexports2013=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2013', product='Total')
mexico_USexports2014=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2014', product='Total')
mexico_USexports2015=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2015', product='Total')
mexico_USexports2016=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2016', product='Total')
mexico_USexports2017=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2017', product='Total')
mexico_USexports2018=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2018', product='Total')
mexico_USexports2019=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2019', product='Total')
mexico_USexports2020=wits.get_indicator('XPRT-TRD-VL', reporter='mex', partner='usa', year='2020', product='Total')

# %%
list_mexico_USimports=[mexico_USimports2006,mexico_USimports2007,mexico_USimports2008,mexico_USimports2009,mexico_USimports2010,mexico_USimports2011,mexico_USimports2012,mexico_USimports2013,mexico_USimports2014,mexico_USimports2015,mexico_USimports2016,mexico_USimports2017,mexico_USimports2018,mexico_USimports2019,mexico_USimports2020]

list_mexico_USexports=[mexico_USexports2006,mexico_USexports2007,mexico_USexports2008,mexico_USexports2009,mexico_USexports2010,mexico_USexports2011,mexico_USexports2012,mexico_USexports2013,mexico_USexports2014,mexico_USexports2015,mexico_USexports2016,mexico_USexports2017,mexico_USexports2018,mexico_USexports2019,mexico_USexports2020]

# %%
for dataframe in list_mexico_USimports:
    dataframe.reset_index(inplace=True)

for dataframe in list_mexico_USexports:
    dataframe.reset_index(inplace=True)

for dataframe in list_mexico_USimports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

for dataframe in list_mexico_USexports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

# %%
mexico_USimports=[df.set_index('Year') for df in list_mexico_USimports]

mexico_USimports=pd.concat(mexico_USimports, axis=0)

mexico_USimports=mexico_USimports.reset_index()

mexico_USimports=mexico_USimports.rename(columns={'Value':'Imports from US' })

# %%
mexico_USexports=[df.set_index('Year') for df in list_mexico_USexports]
mexico_USexports=pd.concat(mexico_USexports, axis=0)
mexico_USexports=mexico_USexports.reset_index()
mexico_USexports=mexico_USexports.rename(columns={'Value':'Exports to US'})

mexico_UScurrentaccount=pd.merge(mexico_USimports,mexico_USexports)

# %%
mexico_UScurrentaccount['Current Account (*US*)']=mexico_UScurrentaccount['Exports to US']-mexico_UScurrentaccount['Imports from US']

mexico_UScurrentaccount
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)
# 0   2006     1.308098e+08   2.121318e+08            8.132196e+07
# 1   2007     1.399306e+08   2.233878e+08            8.345728e+07
# 2   2008     1.517464e+08   2.337939e+08            8.204752e+07
# 3   2009     1.127887e+08   1.854485e+08            7.265978e+07
# 4   2010     1.454504e+08   2.388589e+08            9.340851e+07
# 5   2011     1.748785e+08   2.747201e+08            9.984165e+07
# 6   2012     1.856839e+08   2.881787e+08            1.024948e+08
# 7   2013     1.877584e+08   2.994868e+08            1.117283e+08
# 8   2014     1.958562e+08   3.186526e+08            1.227965e+08
# 9   2015     1.873081e+08   3.091741e+08            1.218660e+08
# 10  2016     1.799181e+08   3.029086e+08            1.229905e+08
# 11  2017     1.949784e+08   3.272152e+08            1.322368e+08
# 12  2018     2.162702e+08   3.568928e+08            1.406226e+08
# ...

# %%
india_USimports2006=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2006', product='Total')
india_USimports2007=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2007', product='Total')
india_USimports2008=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2008', product='Total')
india_USimports2009=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2009', product='Total')
india_USimports2010=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2010', product='Total')
india_USimports2011=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2011', product='Total')
india_USimports2012=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2012', product='Total')
india_USimports2013=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2013', product='Total')
india_USimports2014=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2014', product='Total')
india_USimports2015=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2015', product='Total')
india_USimports2016=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2016', product='Total')
india_USimports2017=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2017', product='Total')
india_USimports2018=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2018', product='Total')
india_USimports2019=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2019', product='Total')
india_USimports2020=wits.get_indicator('MPRT-TRD-VL', reporter='ind', partner='usa', year ='2020', product='Total')

# %%
india_USexports2006=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2006', product='Total')
india_USexports2007=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2007', product='Total')
india_USexports2008=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2008', product='Total')
india_USexports2009=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2009', product='Total')
india_USexports2010=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2010', product='Total')
india_USexports2011=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2011', product='Total')
india_USexports2012=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2012', product='Total')
india_USexports2013=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2013', product='Total')
india_USexports2014=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2014', product='Total')
india_USexports2015=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2015', product='Total')
india_USexports2016=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2016', product='Total')
india_USexports2017=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2017', product='Total')
india_USexports2018=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2018', product='Total')
india_USexports2019=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2019', product='Total')
india_USexports2020=wits.get_indicator('XPRT-TRD-VL', reporter='ind', partner='usa', year='2020', product='Total')

# %%
list_india_USimports=[india_USimports2006,india_USimports2007,india_USimports2008,india_USimports2009,india_USimports2010,india_USimports2011,india_USimports2012,india_USimports2013,india_USimports2014,india_USimports2015,india_USimports2016,india_USimports2017,india_USimports2018,india_USimports2019,india_USimports2020]
list_india_USexports=[india_USexports2006,india_USexports2007,india_USexports2008,india_USexports2009,india_USexports2010,india_USexports2011,india_USexports2012,india_USexports2013,india_USexports2014,india_USexports2015,india_USexports2016,india_USexports2017,india_USexports2018,india_USexports2019,india_USexports2020]

# %%
for dataframe in list_india_USimports:
    dataframe.reset_index(inplace=True)

for dataframe in list_india_USexports:
    dataframe.reset_index(inplace=True)

for dataframe in list_india_USimports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

for dataframe in list_india_USexports:
    dataframe=dataframe.drop(columns=['Freq', 'Reporter', 'Partner', 'Indicator', 'DataSource', 'ProductCode'], inplace=True)

# %%
india_USimports=[df.set_index('Year') for df in list_india_USimports]

india_USimports=pd.concat(india_USimports, axis=0)

india_USimports=india_USimports.reset_index()

india_USimports=india_USimports.rename(columns={'Value':'Imports from US'})

# %%
india_USexports=[df.set_index('Year') for df in list_india_USexports]
india_USexports=pd.concat(india_USexports, axis=0)
india_USexports=india_USexports.reset_index()
india_USexports=india_USexports.rename(columns={'Value':'Exports to US'})

india_UScurrentaccount=pd.merge(india_USimports,india_USexports)

# %%
india_UScurrentaccount['Current Account (*US*)']=india_UScurrentaccount['Exports to US']-india_UScurrentaccount['Imports from US']

india_UScurrentaccount
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)
# 0   2006     1.132148e+07   1.870545e+07            7.383975e+06
# 1   2007     1.420637e+07   2.013333e+07            5.926968e+06
# 2   2008     2.448713e+07   2.140712e+07           -3.080005e+06
# 3   2009     1.599842e+07   1.912820e+07            3.129777e+06
# 4   2010     1.909629e+07   2.358744e+07            4.491155e+06
# 5   2011     2.257388e+07   3.291904e+07            1.034516e+07
# 6   2012     2.410544e+07   3.717069e+07            1.306524e+07
# 7   2013     2.260034e+07   4.195673e+07            1.935639e+07
# 8   2014     2.043973e+07   4.268474e+07            2.224501e+07
# 9   2015     2.046365e+07   4.031270e+07            1.984905e+07
# 10  2016     2.039524e+07   4.199247e+07            2.159723e+07
# 11  2017     2.408616e+07   4.601808e+07            2.193192e+07
# 12  2018     3.890447e+07   5.162859e+07            1.272411e+07
# ...

# %%
mexico_US_currentaccount_differentials=pd.merge(mexico_UScurrentaccount,Mexico_currentaccount_differential)

# %%
mexico_US_currentaccount_differentials
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)  \
# 0   2006     1.308098e+08   2.121318e+08            8.132196e+07
# 1   2007     1.399306e+08   2.233878e+08            8.345728e+07
# 2   2008     1.517464e+08   2.337939e+08            8.204752e+07
# 3   2009     1.127887e+08   1.854485e+08            7.265978e+07
# 4   2010     1.454504e+08   2.388589e+08            9.340851e+07
# 5   2011     1.748785e+08   2.747201e+08            9.984165e+07
# 6   2012     1.856839e+08   2.881787e+08            1.024948e+08
# 7   2013     1.877584e+08   2.994868e+08            1.117283e+08
# 8   2014     1.958562e+08   3.186526e+08            1.227965e+08
# 9   2015     1.873081e+08   3.091741e+08            1.218660e+08
# 10  2016     1.799181e+08   3.029086e+08            1.229905e+08
# 11  2017     1.949784e+08   3.272152e+08            1.322368e+08
# 12  2018     2.162702e+08   3.568928e+08            1.406226e+08
# ...

# %%
mexico_US_currentaccount_differentials['import from US share of Total Imports'] = (mexico_US_currentaccount_differentials['Imports from US'] / 
                  mexico_US_currentaccount_differentials['Imports']) * 100

# %%
mexico_US_currentaccount_differentials['Export to US share of Total Exports'] = (mexico_US_currentaccount_differentials['Exports to US'] / 
                  mexico_US_currentaccount_differentials['Exports']) * 100

# %%
mexico_US_currentaccount_differentials
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)  \
# 0   2006     1.308098e+08   2.121318e+08            8.132196e+07
# 1   2007     1.399306e+08   2.233878e+08            8.345728e+07
# 2   2008     1.517464e+08   2.337939e+08            8.204752e+07
# 3   2009     1.127887e+08   1.854485e+08            7.265978e+07
# 4   2010     1.454504e+08   2.388589e+08            9.340851e+07
# 5   2011     1.748785e+08   2.747201e+08            9.984165e+07
# 6   2012     1.856839e+08   2.881787e+08            1.024948e+08
# 7   2013     1.877584e+08   2.994868e+08            1.117283e+08
# 8   2014     1.958562e+08   3.186526e+08            1.227965e+08
# 9   2015     1.873081e+08   3.091741e+08            1.218660e+08
# 10  2016     1.799181e+08   3.029086e+08            1.229905e+08
# 11  2017     1.949784e+08   3.272152e+08            1.322368e+08
# 12  2018     2.162702e+08   3.568928e+08            1.406226e+08
# ...

# %%
india_US_currentaccount_differentials=pd.merge(india_UScurrentaccount,India_currentaccount_differential)

# %%
india_US_currentaccount_differentials
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)  \
# 0   2006     1.132148e+07   1.870545e+07            7.383975e+06
# 1   2007     1.420637e+07   2.013333e+07            5.926968e+06
# 2   2008     2.448713e+07   2.140712e+07           -3.080005e+06
# 3   2009     1.599842e+07   1.912820e+07            3.129777e+06
# 4   2010     1.909629e+07   2.358744e+07            4.491155e+06
# 5   2011     2.257388e+07   3.291904e+07            1.034516e+07
# 6   2012     2.410544e+07   3.717069e+07            1.306524e+07
# 7   2013     2.260034e+07   4.195673e+07            1.935639e+07
# 8   2014     2.043973e+07   4.268474e+07            2.224501e+07
# 9   2015     2.046365e+07   4.031270e+07            1.984905e+07
# 10  2016     2.039524e+07   4.199247e+07            2.159723e+07
# 11  2017     2.408616e+07   4.601808e+07            2.193192e+07
# 12  2018     3.890447e+07   5.162859e+07            1.272411e+07
# ...

# %%
india_US_currentaccount_differentials['Import from US share of Total Imports'] = (india_US_currentaccount_differentials['Imports from US'] / 
                  india_US_currentaccount_differentials['Imports']) * 100

# %%
india_US_currentaccount_differentials['Export to US share of Total Exports'] = (india_US_currentaccount_differentials['Exports to US'] / 
                  india_US_currentaccount_differentials['Exports']) * 100

# %%
india_US_currentaccount_differentials
# Out:
#     Year  Imports from US  Exports to US  Current Account (*US*)  \
# 0   2006     1.132148e+07   1.870545e+07            7.383975e+06
# 1   2007     1.420637e+07   2.013333e+07            5.926968e+06
# 2   2008     2.448713e+07   2.140712e+07           -3.080005e+06
# 3   2009     1.599842e+07   1.912820e+07            3.129777e+06
# 4   2010     1.909629e+07   2.358744e+07            4.491155e+06
# 5   2011     2.257388e+07   3.291904e+07            1.034516e+07
# 6   2012     2.410544e+07   3.717069e+07            1.306524e+07
# 7   2013     2.260034e+07   4.195673e+07            1.935639e+07
# 8   2014     2.043973e+07   4.268474e+07            2.224501e+07
# 9   2015     2.046365e+07   4.031270e+07            1.984905e+07
# 10  2016     2.039524e+07   4.199247e+07            2.159723e+07
# 11  2017     2.408616e+07   4.601808e+07            2.193192e+07
# 12  2018     3.890447e+07   5.162859e+07            1.272411e+07
# ...

# %%
mexico_US_currentaccount_differentials.plot.bar(x='Year', y='import from US share of Total Imports', title=' Mexico Imports from US as % of Current Account', legend=False)
# Out:
# <AxesSubplot:title={'center':' Mexico Imports from US as % of Current Account'}, xlabel='Year'>

# %%
mexico_US_currentaccount_differentials.plot.bar(x='Year', y='Export to US share of Total Exports', title=' Mexico Exports to US as % of Current Account', legend=False)
# Out:
# <AxesSubplot:title={'center':' Mexico Exports to US as % of Current Account'}, xlabel='Year'>

# %%
india_US_currentaccount_differentials.plot.bar(x='Year', y='Import from US share of Total Imports', title='India Imports from US as % of Current Account', legend=False)
# Out:
# <AxesSubplot:title={'center':'India Imports from US as % of Current Account'}, xlabel='Year'>

# %%
india_US_currentaccount_differentials.plot.bar(x='Year', y='Export to US share of Total Exports', title='India Exports from US as % of Current Account', legend=False)
# Out:
# <AxesSubplot:title={'center':'India Exports from US as % of Current Account'}, xlabel='Year'>

# %%
india_US_currentaccount_differentials.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.772573
# Exports to US                                 0.772573       1.000000
# Current Account (*US*)                        0.281866       0.826944
# India-US Interest Rate Differential           0.379128       0.602165
# Imports                                       0.846583       0.847642
# Exports                                       0.703648       0.894620
# Current Account                              -0.863234      -0.631422
# Import from US share of Total Imports         0.222873      -0.211446
# Export to US share of Total Exports           0.364609       0.611111
#
#                                        Current Account (*US*)  \
# Imports from US                                      0.281866
# Exports to US                                        0.826944
# Current Account (*US*)                               1.000000
# ...

# %%
mexico_US_currentaccount_differentials.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.984677
# Exports to US                                 0.984677       1.000000
# Current Account (*US*)                        0.922690       0.975785
# Mexico-US Interest Rate Differential          0.298561       0.368309
# Imports                                       0.987139       0.996738
# Exports                                       0.985622       0.996428
# Current Account                               0.074582       0.088589
# import from US share of Total Imports        -0.525034      -0.640804
# Export to US share of Total Exports          -0.608972      -0.564916
#
#                                        Current Account (*US*)  \
# Imports from US                                      0.922690
# Exports to US                                        0.975785
# Current Account (*US*)                               1.000000
# ...

# %%
#### Stock market data

# %%
import yfinance as yf
from datetime import datetime

# %%
### getting mexican stock data
mexipc=yf.Ticker("^MXX")

end_date = datetime.now().strftime('%Y-%m-%d')
mexipcdatahist=mexipc.history(start='2006-01-01', end=end_date)


mexipcdatahist.reset_index(inplace=True)

mexipcdatahist['Date']=mexipcdatahist['Date'].dt.strftime('%Y-%m-%d')

# %%
#### getting historical data 
mexipcdatahist
# Out:
#             Date          Open          High           Low         Close  \
# 0     2006-01-02  17802.710938  17926.970703  17786.240234  17925.699219
# 1     2006-01-03  17925.449219  18503.189453  17925.449219  18500.689453
# 2     2006-01-04  18501.949219  18687.839844  18501.949219  18669.230469
# 3     2006-01-05  18669.230469  18768.740234  18592.689453  18608.339844
# 4     2006-01-06  18608.339844  18786.269531  18575.750000  18736.779297
# ...          ...           ...           ...           ...           ...
# 4265  2023-01-06  50800.839844  52004.828125  50618.308594  51730.500000
# 4266  2023-01-09  51770.101562  52460.480469  51744.839844  52280.050781
# 4267  2023-01-10  52297.710938  52564.109375  52180.851562  52344.019531
# 4268  2023-01-11  52348.449219  53508.750000  52348.449219  53209.000000
# 4269  2023-01-12  53228.449219  53859.000000  53215.511719  53593.859375
#
#          Volume  Dividends  Stock Splits
# 0       8889000        0.0           0.0
# ...

# %%
mexipcdatahist=mexipcdatahist.drop(columns=['Open', 'High', 'Low',  'Volume', 'Dividends', 'Stock Splits'])

# %%
mexipcdatahist
# Out:
#             Date         Close
# 0     2006-01-02  17925.699219
# 1     2006-01-03  18500.689453
# 2     2006-01-04  18669.230469
# 3     2006-01-05  18608.339844
# 4     2006-01-06  18736.779297
# ...          ...           ...
# 4265  2023-01-06  51730.500000
# 4266  2023-01-09  52280.050781
# 4267  2023-01-10  52344.019531
# 4268  2023-01-11  53209.000000
# 4269  2023-01-12  53593.859375
#
# [4270 rows x 2 columns]

# %%
#### getting average 
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'

start_date_17='2017-01-01'
end_date_17='2017-12-31'

start_date_18='2018-01-01'
end_date_18='2018-12-31'

start_date_19='2019-01-01'
end_date_19='2019-12-31'

#start_date_20='2020-01-01'
#end_date_20='2020-12-31'



year06 = (mexipcdatahist['Date'] > start_date_06) & (mexipcdatahist['Date'] <= end_date_06)
year07 = (mexipcdatahist['Date'] > start_date_07) & (mexipcdatahist['Date'] <= end_date_07)
year08 = (mexipcdatahist['Date'] > start_date_08) & (mexipcdatahist['Date'] <= end_date_08)
year09 = (mexipcdatahist['Date'] > start_date_09) & (mexipcdatahist['Date'] <= end_date_09)
year10 = (mexipcdatahist['Date'] > start_date_10) & (mexipcdatahist['Date'] <= end_date_10)
year10 = (mexipcdatahist['Date'] > start_date_10) & (mexipcdatahist['Date'] <= end_date_10)
year11 = (mexipcdatahist['Date'] > start_date_11) & (mexipcdatahist['Date'] <= end_date_11)
year12 = (mexipcdatahist['Date'] > start_date_12) & (mexipcdatahist['Date'] <= end_date_12)
year13 = (mexipcdatahist['Date'] > start_date_13) & (mexipcdatahist['Date'] <= end_date_13)
year14 = (mexipcdatahist['Date'] > start_date_14) & (mexipcdatahist['Date'] <= end_date_14)
year15 = (mexipcdatahist['Date'] > start_date_15) & (mexipcdatahist['Date'] <= end_date_15)
year16 = (mexipcdatahist['Date'] > start_date_16) & (mexipcdatahist['Date'] <= end_date_16)
year17 = (mexipcdatahist['Date'] > start_date_17) & (mexipcdatahist['Date'] <= end_date_17)
year18 = (mexipcdatahist['Date'] > start_date_18) & (mexipcdatahist['Date'] <= end_date_18)
year19 = (mexipcdatahist['Date'] > start_date_19) & (mexipcdatahist['Date'] <= end_date_19)
#year20 = (IndiaUS10yryield['Date'] > start_date_20) & (IndiaUS10yryield['Date'] <= end_date_20)

# %%
IPC06=mexipcdatahist.loc[year06]
IPC07=mexipcdatahist.loc[year07]
IPC08=mexipcdatahist.loc[year08]
IPC09=mexipcdatahist.loc[year09]
IPC10=mexipcdatahist.loc[year10]
IPC11=mexipcdatahist.loc[year11]
IPC12=mexipcdatahist.loc[year12]
IPC13=mexipcdatahist.loc[year13]
IPC14=mexipcdatahist.loc[year14]
IPC15=mexipcdatahist.loc[year15]
IPC16=mexipcdatahist.loc[year16]
IPC17=mexipcdatahist.loc[year17]
IPC18=mexipcdatahist.loc[year18]
IPC19=mexipcdatahist.loc[year19]

# %%
MEXIPC06=IPC06['Close'].mean()
MEXIPC07=IPC07['Close'].mean()
MEXIPC08=IPC08['Close'].mean()
MEXIPC09=IPC09['Close'].mean()
MEXIPC10=IPC10['Close'].mean()
MEXIPC11=IPC11['Close'].mean()
MEXIPC12=IPC12['Close'].mean()
MEXIPC13=IPC13['Close'].mean()
MEXIPC14=IPC14['Close'].mean()
MEXIPC15=IPC15['Close'].mean()
MEXIPC16=IPC16['Close'].mean()
MEXIPC17=IPC17['Close'].mean()
MEXIPC18=IPC18['Close'].mean()
MEXIPC19=IPC19['Close'].mean()

# %%
data= [['2006', MEXIPC06],['2007', MEXIPC07],['2008', MEXIPC08],['2009', MEXIPC09],['2010', MEXIPC10],['2011', MEXIPC11],['2012', MEXIPC12],['2013', MEXIPC13],['2014', MEXIPC14],['2015', MEXIPC15],['2016', MEXIPC16],['2017', MEXIPC17],['2018', MEXIPC18],['2019', MEXIPC19]]
MexIpc=pd.DataFrame(data,columns=['Year', 'IPC Value'])
MexIpc
# Out:
#     Year     IPC Value
# 0   2006  20697.949797
# 1   2007  29712.972272
# 2   2008  26766.929517
# 3   2009  25372.536487
# 4   2010  33283.119847
# 5   2011  35895.875241
# 6   2012  39730.177853
# 7   2013  41926.117705
# 8   2014  42623.024828
# 9   2015  43905.928131
# 10  2016  45602.364924
# 11  2017  49035.249564
# 12  2018  47199.990491
# 13  2019  42971.744024

# %%
#### downloading consumer sentiemnt data from FRED imported from excel 
USconsumersentiemnet=pd.read_excel('/Users/ishaansm/Desktop/UMCSENT.xls')

# %%
USconsumersentiemnet
# Out:
#     observation_date  UMCSENT
# 0         2006-01-01     91.2
# 1         2006-02-01     86.7
# 2         2006-03-01     88.9
# 3         2006-04-01     87.4
# 4         2006-05-01     79.1
# ..               ...      ...
# 175       2020-08-01     74.1
# 176       2020-09-01     80.4
# 177       2020-10-01     81.8
# 178       2020-11-01     76.9
# 179       2020-12-01     80.7
#
# [180 rows x 2 columns]

# %%
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'

start_date_17='2017-01-01'
end_date_17='2017-12-31'

start_date_18='2018-01-01'
end_date_18='2018-12-31'

start_date_19='2019-01-01'
end_date_19='2019-12-31'

#start_date_20='2020-01-01'
#end_date_20='2020-12-31'



year06 = (USconsumersentiemnet['observation_date'] > start_date_06) & (USconsumersentiemnet['observation_date'] <= end_date_06)
year07 = (USconsumersentiemnet['observation_date'] > start_date_07) & (USconsumersentiemnet['observation_date'] <= end_date_07)
year08 = (USconsumersentiemnet['observation_date'] > start_date_08) & (USconsumersentiemnet['observation_date'] <= end_date_08)
year09 = (USconsumersentiemnet['observation_date'] > start_date_09) & (USconsumersentiemnet['observation_date'] <= end_date_09)
year10 = (USconsumersentiemnet['observation_date'] > start_date_10) & (USconsumersentiemnet['observation_date'] <= end_date_10)
year10 = (USconsumersentiemnet['observation_date'] > start_date_10) & (USconsumersentiemnet['observation_date'] <= end_date_10)
year11 = (USconsumersentiemnet['observation_date'] > start_date_11) & (USconsumersentiemnet['observation_date'] <= end_date_11)
year12 = (USconsumersentiemnet['observation_date'] > start_date_12) & (USconsumersentiemnet['observation_date'] <= end_date_12)
year13 = (USconsumersentiemnet['observation_date'] > start_date_13) & (USconsumersentiemnet['observation_date'] <= end_date_13)
year14 = (USconsumersentiemnet['observation_date'] > start_date_14) & (USconsumersentiemnet['observation_date'] <= end_date_14)
year15 = (USconsumersentiemnet['observation_date'] > start_date_15) & (USconsumersentiemnet['observation_date'] <= end_date_15)
year16 = (USconsumersentiemnet['observation_date'] > start_date_16) & (USconsumersentiemnet['observation_date'] <= end_date_16)
year17 = (USconsumersentiemnet['observation_date'] > start_date_17) & (USconsumersentiemnet['observation_date'] <= end_date_17)
year18 = (USconsumersentiemnet['observation_date'] > start_date_18) & (USconsumersentiemnet['observation_date'] <= end_date_18)
year19 = (USconsumersentiemnet['observation_date'] > start_date_19) & (USconsumersentiemnet['observation_date'] <= end_date_19)
#year20 = (IndiaUS10yryield['Date'] > start_date_20) & (IndiaUS10yryield['Date'] <= end_date_20)

# %%
ConsumSent06=USconsumersentiemnet.loc[year06]
ConsumSent07=USconsumersentiemnet.loc[year07]
ConsumSent08=USconsumersentiemnet.loc[year08]
ConsumSent09=USconsumersentiemnet.loc[year09]
ConsumSent10=USconsumersentiemnet.loc[year10]
ConsumSent11=USconsumersentiemnet.loc[year11]
ConsumSent12=USconsumersentiemnet.loc[year12]
ConsumSent13=USconsumersentiemnet.loc[year13]
ConsumSent14=USconsumersentiemnet.loc[year14]
ConsumSent15=USconsumersentiemnet.loc[year15]
ConsumSent16=USconsumersentiemnet.loc[year16]
ConsumSent17=USconsumersentiemnet.loc[year17]
ConsumSent18=USconsumersentiemnet.loc[year18]
ConsumSent19=USconsumersentiemnet.loc[year19]
#IndiaUS10yr20=IndiaUS10yryield.loc[year20]

# %%
USConsumSent06=ConsumSent06['UMCSENT'].mean()
USConsumSent07=ConsumSent07['UMCSENT'].mean()
USConsumSent08=ConsumSent08['UMCSENT'].mean()
USConsumSent09=ConsumSent09['UMCSENT'].mean()
USConsumSent10=ConsumSent10['UMCSENT'].mean()
USConsumSent11=ConsumSent11['UMCSENT'].mean()
USConsumSent12=ConsumSent12['UMCSENT'].mean()
USConsumSent13=ConsumSent13['UMCSENT'].mean()
USConsumSent14=ConsumSent14['UMCSENT'].mean()
USConsumSent15=ConsumSent15['UMCSENT'].mean()
USConsumSent16=ConsumSent16['UMCSENT'].mean()
USConsumSent17=ConsumSent17['UMCSENT'].mean()
USConsumSent18=ConsumSent18['UMCSENT'].mean()
USConsumSent19=ConsumSent19['UMCSENT'].mean()
#Inddiff20=IndiaUS10yr20['India-US Differential'].mean()

# %%
data= [['2006', USConsumSent06],['2007', USConsumSent07],['2008', USConsumSent08],['2009', USConsumSent09],['2010', USConsumSent10],['2011', USConsumSent11],['2012', USConsumSent12],['2013', USConsumSent13],['2014', USConsumSent14],['2015', USConsumSent15],['2016', USConsumSent16],['2017', USConsumSent17],['2018', USConsumSent18],['2019', USConsumSent19]]
USConsumSent=pd.DataFrame(data,columns=['Year', 'US Consumer Sentiment'])
USConsumSent
# Out:
#     Year  US Consumer Sentiment
# 0   2006              86.954545
# 1   2007              84.554545
# 2   2008              62.418182
# 3   2009              66.718182
# 4   2010              71.609091
# 5   2011              66.727273
# 6   2012              76.681818
# 7   2013              79.700000
# 8   2014              84.390909
# 9   2015              92.472727
# 10  2016              91.827273
# 11  2017              96.609091
# 12  2018              98.609091
# 13  2019              96.418182

# %%
MexIPC_USConsumSent=pd.merge(MexIpc,USConsumSent)

# %%
MexIPC_USConsumSent.corr()
# Out:
#                        IPC Value  US Consumer Sentiment
# IPC Value               1.000000               0.640002
# US Consumer Sentiment   0.640002               1.000000

# %%
### Looking at correlation between the IPC and S&P 500 and Mexican Differentials 


### Getting S&P 500 data
SP500=yf.Ticker("^GSPC")

SP500hist=SP500.history(start='2006-01-01', end=end_date)
end_date = datetime.now().strftime('%Y-%m-%d')

SP500hist.reset_index(inplace=True)

SP500hist['Date']=SP500hist['Date'].dt.strftime('%Y-%m-%d')


SP500hist=SP500hist.drop(columns=['Open', 'High', 'Low',  'Volume', 'Dividends', 'Stock Splits'])

SP500hist
# Out:
#             Date        Close
# 0     2006-01-03  1268.800049
# 1     2006-01-04  1273.459961
# 2     2006-01-05  1273.479980
# 3     2006-01-06  1285.449951
# 4     2006-01-09  1290.150024
# ...          ...          ...
# 4282  2023-01-06  3895.080078
# 4283  2023-01-09  3892.090088
# 4284  2023-01-10  3919.250000
# 4285  2023-01-11  3969.610107
# 4286  2023-01-12  3983.169922
#
# [4287 rows x 2 columns]

# %%
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'

start_date_17='2017-01-01'
end_date_17='2017-12-31'

start_date_18='2018-01-01'
end_date_18='2018-12-31'

start_date_19='2019-01-01'
end_date_19='2019-12-31'

#start_date_20='2020-01-01'
#end_date_20='2020-12-31'



year06 = (SP500hist['Date'] > start_date_06) & (SP500hist['Date'] <= end_date_06)
year07 = (SP500hist['Date'] > start_date_07) & (SP500hist['Date'] <= end_date_07)
year08 = (SP500hist['Date'] > start_date_08) & (SP500hist['Date'] <= end_date_08)
year09 = (SP500hist['Date'] > start_date_09) & (SP500hist['Date'] <= end_date_09)
year10 = (SP500hist['Date'] > start_date_10) & (SP500hist['Date'] <= end_date_10)
year10 = (SP500hist['Date'] > start_date_10) & (SP500hist['Date'] <= end_date_10)
year11 = (SP500hist['Date'] > start_date_11) & (SP500hist['Date'] <= end_date_11)
year12 = (SP500hist['Date'] > start_date_12) & (SP500hist['Date'] <= end_date_12)
year13 = (SP500hist['Date'] > start_date_13) & (SP500hist['Date'] <= end_date_13)
year14 = (SP500hist['Date'] > start_date_14) & (SP500hist['Date'] <= end_date_14)
year15 = (SP500hist['Date'] > start_date_15) & (SP500hist['Date'] <= end_date_15)
year16 = (SP500hist['Date'] > start_date_16) & (SP500hist['Date'] <= end_date_16)
year17 = (SP500hist['Date'] > start_date_17) & (SP500hist['Date'] <= end_date_17)
year18 = (SP500hist['Date'] > start_date_18) & (SP500hist['Date'] <= end_date_18)
year19 = (SP500hist['Date'] > start_date_19) & (SP500hist['Date'] <= end_date_19)
#year20 = (IndiaUS10yryield['Date'] > start_date_20) & (IndiaUS10yryield['Date'] <= end_date_20)

# %%
SP50006=SP500hist.loc[year06]
SP50007=SP500hist.loc[year07]
SP50008=SP500hist.loc[year08]
SP50009=SP500hist.loc[year09]
SP50010=SP500hist.loc[year10]
SP50011=SP500hist.loc[year11]
SP50012=SP500hist.loc[year12]
SP50013=SP500hist.loc[year13]
SP50014=SP500hist.loc[year14]
SP50015=SP500hist.loc[year15]
SP50016=SP500hist.loc[year16]
SP50017=SP500hist.loc[year17]
SP50018=SP500hist.loc[year18]
SP50019=SP500hist.loc[year19]
#IndiaUS10yr20=IndiaUS10yryield.loc[year20]

# %%
SP50006=SP50006['Close'].mean()
SP50007=SP50007['Close'].mean()
SP50008=SP50008['Close'].mean()
SP50009=SP50009['Close'].mean()
SP50010=SP50010['Close'].mean()
SP50011=SP50011['Close'].mean()
SP50012=SP50012['Close'].mean()
SP50013=SP50013['Close'].mean()
SP50014=SP50014['Close'].mean()
SP50015=SP50015['Close'].mean()
SP50016=SP50016['Close'].mean()
SP50017=SP50017['Close'].mean()
SP50018=SP50018['Close'].mean()
SP50019=SP50019['Close'].mean()
#Inddiff20=IndiaUS10yr20['India-US Differential'].mean()

# %%
data= [['2006', SP50006],['2007', SP50007],['2008', SP50008],['2009', SP50009],['2010', SP50010],['2011', SP50011],['2012', SP50012],['2013', SP50013],['2014', SP50014],['2015', SP50015],['2016', SP50016],['2017', SP50017],['2018', SP50018],['2019', SP50019]]
SP500=pd.DataFrame(data,columns=['Year', 'SP 500 Value'])
SP500
# Out:
#     Year  SP 500 Value
# 0   2006   1310.461236
# 1   2007   1477.184342
# 2   2008   1220.042056
# 3   2009    948.046388
# 4   2010   1139.965512
# 5   2011   1267.638809
# 6   2012   1379.354160
# 7   2013   1643.798968
# 8   2014   1931.376110
# 9   2015   2061.067741
# 10  2016   2094.651264
# 11  2017   2449.076379
# 12  2018   2746.214183
# 13  2019   2913.356380

# %%
MexIPC_USSP500=pd.merge(SP500,MexIpc)

# %%
MexIPC_USSP500.corr()
# Out:
#               SP 500 Value  IPC Value
# SP 500 Value      1.000000   0.785198
# IPC Value         0.785198   1.000000

# %%
MexDiff_SP500=pd.merge(Mexdiff,SP500)

# %%
MexDiff_SP500.corr()
# Out:
#                                       Mexico-US Interest Rate Differential  \
# Mexico-US Interest Rate Differential                              1.000000
# SP 500 Value                                                      0.495962
#
#                                       SP 500 Value
# Mexico-US Interest Rate Differential      0.495962
# SP 500 Value                              1.000000

# %%
mexico_US_currentaccount_differentials_IPC=pd.merge(mexico_US_currentaccount_differentials,MexIpc)

# %%
mexico_US_currentaccount_differentials_IPC.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.984677
# Exports to US                                 0.984677       1.000000
# Current Account (*US*)                        0.922690       0.975785
# Mexico-US Interest Rate Differential          0.298561       0.368309
# Imports                                       0.987139       0.996738
# Exports                                       0.985622       0.996428
# Current Account                               0.074582       0.088589
# import from US share of Total Imports        -0.525034      -0.640804
# Export to US share of Total Exports          -0.608972      -0.564916
# IPC Value                                     0.908453       0.919886
#
#                                        Current Account (*US*)  \
# Imports from US                                      0.922690
# Exports to US                                        0.975785
# ...

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent=pd.merge(mexico_US_currentaccount_differentials_IPC,USConsumSent)

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.984677
# Exports to US                                 0.984677       1.000000
# Current Account (*US*)                        0.922690       0.975785
# Mexico-US Interest Rate Differential          0.298561       0.368309
# Imports                                       0.987139       0.996738
# Exports                                       0.985622       0.996428
# Current Account                               0.074582       0.088589
# import from US share of Total Imports        -0.525034      -0.640804
# Export to US share of Total Exports          -0.608972      -0.564916
# IPC Value                                     0.908453       0.919886
# US Consumer Sentiment                         0.615003       0.699640
#
#                                        Current Account (*US*)  \
# Imports from US                                      0.922690
# ...

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500=pd.merge(mexico_US_currentaccount_differentials_IPC_ConsumerSent,SP500)

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.984677
# Exports to US                                 0.984677       1.000000
# Current Account (*US*)                        0.922690       0.975785
# Mexico-US Interest Rate Differential          0.298561       0.368309
# Imports                                       0.987139       0.996738
# Exports                                       0.985622       0.996428
# Current Account                               0.074582       0.088589
# import from US share of Total Imports        -0.525034      -0.640804
# Export to US share of Total Exports          -0.608972      -0.564916
# IPC Value                                     0.908453       0.919886
# US Consumer Sentiment                         0.615003       0.699640
# SP 500 Value                                  0.823342       0.896616
#
# ...

# %%
#### Adding in ISM PMI manufacturing data

# %%
### downloading ISM PMI data
import quandl 
quandl.ApiConfig.api_key='gYb73gyc4sJDKyeUmmjs'

# %%
ISMPMI=quandl.get("FRED/NAPM", start_date="2006-01-01", end_date="2015-12-31")

# %%
ISMPMI=ISMPMI.reset_index()

# %%
ISMPMI
# Out:
#           DATE  VALUE
# 0   2006-01-01   55.0
# 1   2006-02-01   55.8
# 2   2006-03-01   54.3
# 3   2006-04-01   55.2
# 4   2006-05-01   53.7
# ..         ...    ...
# 115 2015-08-01   51.0
# 116 2015-09-01   50.0
# 117 2015-10-01   49.4
# 118 2015-11-01   48.4
# 119 2015-12-01   48.0
#
# [120 rows x 2 columns]

# %%
ISMPMI=ISMPMI.rename(columns={'DATE':'Date'})
ISMPMI=ISMPMI.rename(columns={'VALUE':'ISM PMI'})
ISMPMI
# Out:
#           Date  ISM PMI
# 0   2006-01-01     55.0
# 1   2006-02-01     55.8
# 2   2006-03-01     54.3
# 3   2006-04-01     55.2
# 4   2006-05-01     53.7
# ..         ...      ...
# 115 2015-08-01     51.0
# 116 2015-09-01     50.0
# 117 2015-10-01     49.4
# 118 2015-11-01     48.4
# 119 2015-12-01     48.0
#
# [120 rows x 2 columns]

# %%
ISMPMI.dtypes
# Out:
# Date       datetime64[ns]
# ISM PMI           float64
# dtype: object

# %%
start_date_06='2006-01-01'
end_date_06='2006-12-31'

start_date_07='2007-01-01'
end_date_07='2007-12-31'

start_date_08='2008-01-01'
end_date_08='2008-12-31'

start_date_09='2009-01-01'
end_date_09='2009-12-31'

start_date_10='2010-01-01'
end_date_10='2010-12-31'

start_date_11='2011-01-01'
end_date_11='2011-12-31'

start_date_12='2012-01-01'
end_date_12='2012-12-31'

start_date_13='2013-01-01'
end_date_13='2013-12-31'

start_date_14='2014-01-01'
end_date_14='2014-12-31'

start_date_15='2015-01-01'
end_date_15='2015-12-31'


start_date_16='2016-01-01'
end_date_16='2016-12-31'


year06 = (ISMPMI['Date'] > start_date_06) & (ISMPMI['Date'] <= end_date_06)
year07 = (ISMPMI['Date'] > start_date_07) & (ISMPMI['Date'] <= end_date_07)
year08 = (ISMPMI['Date'] > start_date_08) & (ISMPMI['Date'] <= end_date_08)
year09 = (ISMPMI['Date'] > start_date_09) & (ISMPMI['Date'] <= end_date_09)
year10 = (ISMPMI['Date'] > start_date_10) & (ISMPMI['Date'] <= end_date_10)
year10 = (ISMPMI['Date'] > start_date_10) & (ISMPMI['Date'] <= end_date_10)
year11 = (ISMPMI['Date'] > start_date_11) & (ISMPMI['Date'] <= end_date_11)
year12 = (ISMPMI['Date'] > start_date_12) & (ISMPMI['Date'] <= end_date_12)
year13 = (ISMPMI['Date'] > start_date_13) & (ISMPMI['Date'] <= end_date_13)
year14 = (ISMPMI['Date'] > start_date_14) & (ISMPMI['Date'] <= end_date_14)
year15 = (ISMPMI['Date'] > start_date_15) & (ISMPMI['Date'] <= end_date_15)
year16 = (ISMPMI['Date'] > start_date_16) & (ISMPMI['Date'] <= end_date_16)

# %%
ISMPMI06=ISMPMI.loc[year06]
ISMPMI07=ISMPMI.loc[year07]
ISMPMI08=ISMPMI.loc[year08]
ISMPMI09=ISMPMI.loc[year09]
ISMPMI10=ISMPMI.loc[year10]
ISMPMI11=ISMPMI.loc[year11]
ISMPMI12=ISMPMI.loc[year12]
ISMPMI13=ISMPMI.loc[year13]
ISMPMI14=ISMPMI.loc[year14]
ISMPMI15=ISMPMI.loc[year15]
ISMPMI16=ISMPMI.loc[year16]

# %%
ISMPMI06=ISMPMI06['ISM PMI'].mean()
ISMPMI07=ISMPMI07['ISM PMI'].mean()
ISMPMI08=ISMPMI08['ISM PMI'].mean()
ISMPMI09=ISMPMI09['ISM PMI'].mean()
ISMPMI10=ISMPMI10['ISM PMI'].mean()
ISMPMI11=ISMPMI11['ISM PMI'].mean()
ISMPMI12=ISMPMI12['ISM PMI'].mean()
ISMPMI13=ISMPMI13['ISM PMI'].mean()
ISMPMI14=ISMPMI14['ISM PMI'].mean()
ISMPMI15=ISMPMI15['ISM PMI'].mean()
ISMPMI16=ISMPMI16['ISM PMI'].mean()

# %%
data= [['2006', ISMPMI06],['2007', ISMPMI07],['2008', ISMPMI08],['2009', ISMPMI09],['2010', ISMPMI10],['2011', ISMPMI11],['2012', ISMPMI12],['2013', ISMPMI13],['2014', ISMPMI14],['2015', ISMPMI15]]
ISMPMI=pd.DataFrame(data,columns=['Year', 'ISM PMI'])
ISMPMI
# Out:
#    Year    ISM PMI
# 0  2006  53.000000
# 1  2007  51.381818
# 2  2008  45.072727
# 3  2009  47.454545
# 4  2010  57.354545
# 5  2011  54.772727
# 6  2012  51.554545
# 7  2013  53.827273
# 8  2014  55.963636
# 9  2015  51.100000

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI=pd.merge(mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500,ISMPMI)

# %%
mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI.corr()
# Out:
#                                        Imports from US  Exports to US  \
# Imports from US                               1.000000       0.990124
# Exports to US                                 0.990124       1.000000
# Current Account (*US*)                        0.931883       0.973537
# Mexico-US Interest Rate Differential         -0.305095      -0.346317
# Imports                                       0.993172       0.994359
# Exports                                       0.993592       0.994169
# Current Account                               0.192280       0.186236
# import from US share of Total Imports        -0.080823      -0.162008
# Export to US share of Total Exports          -0.567461      -0.507195
# IPC Value                                     0.916901       0.940252
# US Consumer Sentiment                         0.323302       0.400655
# SP 500 Value                                  0.758304       0.813246
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

d = pd.DataFrame(data=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI)

corr = d.corr()

f, ax = plt.subplots(figsize=(11, 9))

sns.heatmap(corr, xticklabels=corr.columns,
           yticklabels=corr.columns)

plt.title('Correlation Visualization Heatmap', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Correlation Visualization Heatmap')

# %%
#### Running regressions
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
list(mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI.columns)
# Out:
# ['Year',
#  'Imports from US',
#  'Exports to US',
#  'Current Account (*US*)',
#  'Mexico-US Interest Rate Differential',
#  'Imports',
#  'Exports',
#  'Current Account',
#  'import from US share of Total Imports',
#  'Export to US share of Total Exports',
#  'IPC Value',
#  'US Consumer Sentiment',
#  'SP 500 Value',
#  'ISM PMI']

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value',
 'ISM PMI']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['IPC Value']

x=sm.add_constant(x)
est_0= sm.OLS(y,x).fit()
print(est_0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              IPC Value   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     7.040
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):             0.0216
# Time:                        18:23:23   Log-Likelihood:                -96.149
# No. Observations:                  10   AIC:                             200.3
# Df Residuals:                       6   BIC:                             201.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  -229.5878   2.29e+04     -0.010      0.992   -5.62e+04    5.57e+04
# ...

# %%
print(est_0.params) ### Linear Regression
# Out:
# const                   -229.587823
# US Consumer Sentiment   -548.231604
# SP 500 Value              27.237073
# ISM PMI                  717.052420
# dtype: float64

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['IPC Value']

x=sm.add_constant(x)
est_1= sm.OLS(y,x).fit()
print(est_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              IPC Value   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     7.520
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):             0.0181
# Time:                        18:23:24   Log-Likelihood:                -97.957
# No. Observations:                  10   AIC:                             201.9
# Df Residuals:                       7   BIC:                             202.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  3.033e+04   1.43e+04      2.122      0.071   -3461.195    6.41e+04
# ...

# %%
print(est_1.params) ### removing ISM PMI
# Out:
# const                    30325.402171
# US Consumer Sentiment     -465.755211
# SP 500 Value                27.563201
# dtype: float64

# %%
#### squaring SP 500
mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['SP 500 Value squared']=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['SP 500 Value']**2

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value squared',
 'ISM PMI']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['IPC Value']

x=sm.add_constant(x)
est_2= sm.OLS(y,x).fit()
print(est_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              IPC Value   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     6.870
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):             0.0229
# Time:                        18:23:24   Log-Likelihood:                -96.244
# No. Observations:                  10   AIC:                             200.5
# Df Residuals:                       6   BIC:                             201.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    1.5e+04   2.43e+04      0.618      0.559   -4.44e+04    7.44e+04
# ...

# %%
print(est_2.params) ### squaring SP500
# Out:
# const                    15004.113666
# US Consumer Sentiment     -526.545901
# SP 500 Value squared         0.008601
# ISM PMI                    784.684606
# dtype: float64

# %%
#### taking out ISM PMI 
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value squared']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI['IPC Value']

x=sm.add_constant(x)
est_3= sm.OLS(y,x).fit()
print(est_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              IPC Value   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     6.765
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):             0.0231
# Time:                        18:23:25   Log-Likelihood:                -98.311
# No. Observations:                  10   AIC:                             202.6
# Df Residuals:                       7   BIC:                             203.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  4.804e+04   1.74e+04      2.754      0.028    6788.594    8.93e+04
# ...

# %%
### with interest rate differential 
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value',
 'ISM PMI']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential']

x=sm.add_constant(x)
est_4= sm.OLS(y,x).fit()
print(est_4.summary())
# Out:
#                                      OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential   R-squared:                       0.780
# Model:                                              OLS   Adj. R-squared:                  0.670
# Method:                                   Least Squares   F-statistic:                     7.084
# Date:                                  Fri, 13 Jan 2023   Prob (F-statistic):             0.0213
# Time:                                          18:23:25   Log-Likelihood:               -0.82781
# No. Observations:                                    10   AIC:                             9.656
# Df Residuals:                                         6   BIC:                             10.87
# Df Model:                                             3
# Covariance Type:                              nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
print(est_4.params) ### Linear regression with Interest Rate Differential as dependent
# Out:
# const                    10.546075
# US Consumer Sentiment    -0.043845
# SP 500 Value              0.000312
# ISM PMI                  -0.072867
# dtype: float64

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential']

x=sm.add_constant(x)
est_5= sm.OLS(y,x).fit()
print(est_5.summary())
# Out:
#                                      OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential   R-squared:                       0.591
# Model:                                              OLS   Adj. R-squared:                  0.475
# Method:                                   Least Squares   F-statistic:                     5.065
# Date:                                  Fri, 13 Jan 2023   Prob (F-statistic):             0.0436
# Time:                                          18:23:25   Log-Likelihood:                -3.9202
# No. Observations:                                    10   AIC:                             13.84
# Df Residuals:                                         7   BIC:                             14.75
# Df Model:                                             2
# Covariance Type:                              nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
### logging the value of the interest rate differential


mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential logged']=np.log(mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential'])

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value',
 'ISM PMI']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential logged']

x=sm.add_constant(x)
est_6= sm.OLS(y,x).fit()
print(est_6.summary())
# Out:
#                                          OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential logged   R-squared:                       0.735
# Model:                                                     OLS   Adj. R-squared:                  0.603
# Method:                                          Least Squares   F-statistic:                     5.555
# Date:                                         Fri, 13 Jan 2023   Prob (F-statistic):             0.0363
# Time:                                                 18:23:26   Log-Likelihood:                 11.863
# No. Observations:                                           10   AIC:                            -15.73
# Df Residuals:                                                6   BIC:                            -14.52
# Df Model:                                                    3
# Covariance Type:                                     nonrobust
# ...

# %%
print(est_6.params) ### Regression coeffecient with Interest Rate Differential Logged
# Out:
# const                    2.979954
# US Consumer Sentiment   -0.011420
# SP 500 Value             0.000086
# ISM PMI                 -0.017154
# dtype: float64

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential logged']

x=sm.add_constant(x)
est_7= sm.OLS(y,x).fit()
print(est_7.summary())
# Out:
#                                          OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential logged   R-squared:                       0.576
# Model:                                                     OLS   Adj. R-squared:                  0.455
# Method:                                          Least Squares   F-statistic:                     4.761
# Date:                                         Fri, 13 Jan 2023   Prob (F-statistic):             0.0495
# Time:                                                 18:23:26   Log-Likelihood:                 9.5113
# No. Observations:                                           10   AIC:                            -13.02
# Df Residuals:                                                7   BIC:                            -12.11
# Df Model:                                                    2
# Covariance Type:                                     nonrobust
# ...

# %%
print(est_7.params) ### Regression coeffecient with interest rate differential logged and ISM PMI out
# Out:
# const                    2.248979
# US Consumer Sentiment   -0.013393
# SP 500 Value             0.000078
# dtype: float64

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value squared',
 'ISM PMI']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential logged']

x=sm.add_constant(x)
est_8= sm.OLS(y,x).fit()
print(est_8.summary())
# Out:
#                                          OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential logged   R-squared:                       0.754
# Model:                                                     OLS   Adj. R-squared:                  0.632
# Method:                                          Least Squares   F-statistic:                     6.143
# Date:                                         Fri, 13 Jan 2023   Prob (F-statistic):             0.0293
# Time:                                                 18:23:26   Log-Likelihood:                 12.237
# No. Observations:                                           10   AIC:                            -16.47
# Df Residuals:                                                6   BIC:                            -15.26
# Df Model:                                                    3
# Covariance Type:                                     nonrobust
# ...

# %%
x=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[[ 'US Consumer Sentiment',
 'SP 500 Value squared']]
y=mexico_US_currentaccount_differentials_IPC_ConsumerSent_SP500_ISMPMI[ 'Mexico-US Interest Rate Differential logged']

x=sm.add_constant(x)
est_9= sm.OLS(y,x).fit()
print(est_9.summary())
# Out:
#                                          OLS Regression Results
# ...
# Dep. Variable:     Mexico-US Interest Rate Differential logged   R-squared:                       0.600
# Model:                                                     OLS   Adj. R-squared:                  0.485
# Method:                                          Least Squares   F-statistic:                     5.245
# Date:                                         Fri, 13 Jan 2023   Prob (F-statistic):             0.0406
# Time:                                                 18:23:27   Log-Likelihood:                 9.7959
# No. Observations:                                           10   AIC:                            -13.59
# Df Residuals:                                                7   BIC:                            -12.68
# Df Model:                                                    2
# Covariance Type:                                     nonrobust
# ...

# %%
###### creating matrix


### creating the matrix
column_names=['US Consumer Sentiment', 'ISM PMI', 'US Consumer Sentiment (*w/out ISM PMI)', 'SP500', 'SP500 (*w/out ISM PMI)', 'SP500 squared'] 
row_names=['IPC']

# %%
### inserting values 
matrix=np.reshape((-548.231604, 717.052420, -465.755211, 27.237073, 27.563201,0.008601), (1,6))

# %%
### creating the matrix
MeixcoIPC_RegCoeffmatrix=pd.DataFrame(matrix, columns=column_names, index=row_names)
MeixcoIPC_RegCoeffmatrix
# Out:
#      US Consumer Sentiment    ISM PMI  US Consumer Sentiment (*w/out ISM PMI)  \
# IPC            -548.231604  717.05242                             -465.755211
#
#          SP500  SP500 (*w/out ISM PMI)  SP500 squared
# IPC  27.237073               27.563201       0.008601

# %%
column_names=['US Consumer Sentiment', 'ISM PMI', 'US Consumer Sentiment (*w/out ISM PMI)'] 
row_names=['MEX_US_InterestRateDifferential_logged']

matrix=np.reshape((-0.011420, -0.017154, -0.013393), (1,3))

MexUSinterestratediff_RegCoeffmatrix=pd.DataFrame(matrix, columns=column_names, index=row_names)
MexUSinterestratediff_RegCoeffmatrix
# Out:
#                                         US Consumer Sentiment   ISM PMI  \
# MEX_US_InterestRateDifferential_logged               -0.01142 -0.017154
#
#                                         US Consumer Sentiment (*w/out ISM PMI)
# MEX_US_InterestRateDifferential_logged                               -0.013393
